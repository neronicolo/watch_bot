# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %%
# local machine path
df = pd.read_csv(Path.home()/'programming/projects/watch_bot/data_prep/file_attribs.csv')
# azure machine path
#df = pd.read_csv(Path.home()/'notebooks/programming/projects/watch_bot/data_prep/file_attribs.csv')
df.head()
# Out:
#    image_size_x  image_size_y  \
# 0           960           960
# 1           960           960
# 2           960           960
# 3           720           960
# 4           720           960
#
#                                                 name  dial_visibility  like  \
# 0  nomos_1/nomos/_without_model/nomos_@_the_loupe...              1.0   1.0
# 1  nomos_1/nomos/_without_model/nomos_@_the_loupe...              1.0   0.0
# 2  nomos_1/nomos/_without_model/nomos_@_the_loupe...              0.0   0.0
# 3  nomos_1/nomos/_without_model/nomos_beta_11156_...              1.0   0.0
# 4  nomos_1/nomos/_without_model/nomos_beta_11156_...              1.0   0.0
#
#    image_quality
# 0            1.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            1.0

# %%
# Plot image_size_x next to image_size_y. On one canvas.
fig, axes = plt.subplots(1, 2, figsize=(10,4), tight_layout=True)
axes[0].hist(df['image_size_x']);
axes[1].hist(df['image_size_y']);

# %%
np.random.seed(123)
len = df.shape[0]
rand_num = np.random.randint(len)
file_name = df.iloc[rand_num]['name']
img = plt.imread(Path.home()/'programming/data/watch_bot'/file_name)
# azure machine
#img = plt.imread(Path.home()/'neronicolo/programming/data/watch_bot'/file_name)
plt.imshow(img);

# %%
t,f = df['dial_visibility'].value_counts()
t,f
# Out:
# (8839, 3134)

# %%
t/df.shape[0]
# Out:
# 0.7382443831955232
