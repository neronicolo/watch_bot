# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import check
from pathlib import Path
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %%
dir_path = check.path_check(Path.home()/'programming/data/watch_bot/')
df = pd.read_csv(dir_path/'wfc_file_attribs.csv')
df.head()
# Out:
#    image_size_x  image_size_y  \
# 0           960           960
# 1           960           960
# 2           960           960
# 3           720           960
# 4           720           960
#
#                                                 name  watch_face_visibility  \
# 0  nomos_1/nomos/_without_model/nomos_@_the_loupe...                     -1
# 1  nomos_1/nomos/_without_model/nomos_@_the_loupe...                     -1
# 2  nomos_1/nomos/_without_model/nomos_@_the_loupe...                     -1
# 3  nomos_1/nomos/_without_model/nomos_beta_11156_...                     -1
# 4  nomos_1/nomos/_without_model/nomos_beta_11156_...                     -1
#
#    composition_quality  light_quality  image_quality
# 0                   -1             -1             -1
# 1                   -1             -1             -1
# 2                   -1             -1             -1
# 3                   -1             -1             -1
# 4                   -1             -1             -1

# %%
# Plot image_size_x next to image_size_y. On one canvas.
fig, axes = plt.subplots(1, 2, figsize=(10,4), tight_layout=True)
axes[0].hist(df['image_size_x']);
axes[1].hist(df['image_size_y']);

# %%
#np.random.seed(123)
len = df.shape[0]
rand_num = np.random.randint(len)
file_name = df.iloc[rand_num]['name']

img = plt.imread(dir_path/file_name)
plt.imshow(img);
